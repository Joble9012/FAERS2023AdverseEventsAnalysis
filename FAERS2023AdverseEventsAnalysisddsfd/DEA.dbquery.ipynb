-- %%
-- See and use what catalogs
SHOW CATALOGS;

-- Use the catalog
USE CATALOG john_snow_labs_fda_drug_adverse_events_reporting_system_faers_2023;

-- See and use what schemas
SHOW SCHEMAS IN john_snow_labs_fda_drug_adverse_events_reporting_system_faers_2023;

-- Use the schema
USE SCHEMA fda_drug_adverse_events_reporting_system_faers_2023;

-- See and use what tables
SHOW TABLES;

SELECT * 
FROM fda_adverse_events_reporting_system_drug_reaction_2023;

SELECT * 
FROM fda_adverse_events_reporting_system_demographics_2023;

SELECT * 
FROM fda_adverse_events_reporting_system_patient_outcome_2023;

SELECT * 
FROM fda_adverse_events_reporting_system_drug_2023;
